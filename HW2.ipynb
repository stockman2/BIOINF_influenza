# %% [markdown]
# <a href="https://colab.research.google.com/github/stockman2/BIOINF_influenza/blob/main/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
freeman@mashine:~/Workplace/Prac$ samtools flagstat roommate.bam
361349 + 0 in total (QC-passed reads + QC-failed reads)
358265 + 0 primary
0 + 0 secondary
3084 + 0 supplementary
0 + 0 duplicates
0 + 0 primary duplicates
361116 + 0 mapped (99.94% : N/A)
358032 + 0 primary mapped (99.93% : N/A)
0 + 0 paired in sequencing
0 + 0 read1
0 + 0 read2
0 + 0 properly paired (N/A : N/A)
0 + 0 with itself and mate mapped
0 + 0 singletons (N/A : N/A)
0 + 0 with mate mapped to a different chr
0 + 0 with mate mapped to a different chr (mapQ>=5)

# %%
java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp my.mpileup 
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from my.mpileup
Chrom	Position	Ref	Var	Cons:Cov:Reads1:Reads2:Freq:P-value	StrandFilter:R1+:R1-:R2+:R2-:pval	SamplesRef	SamplesHet	SamplesHom	SamplesNC	Cons:Cov:Reads1:Reads2:Freq:P-value
KF848938.1	72	A	G	G:16794:6:16787:99.96%:0E0	Pass:4:2:10898:5889:1E0	0	0	1	0	G:16794:6:16787:99.96%:0E0
KF848938.1	117	C	T	T:20663:36:20625:99.82%:0E0	Pass:27:9:13462:7163:1E0	0	0	1	0	T:20663:36:20625:99.82%:0E0
KF848938.1	774	T	C	C:38191:8:38177:99.96%:0E0	Pass:7:1:19806:18371:1E0	0	0	1	0	C:38191:8:38177:99.96%:0E0
KF848938.1	999	C	T	T:32115:40:32070:99.86%:0E0	Pass:23:17:17184:14886:1E0	0	0	1	0	T:32115:40:32070:99.86%:0E0
KF848938.1	1260	A	C	C:23033:2:23019:99.94%:0E0	Pass:0:2:9824:13195:1E0	0	0	1	0	C:23033:2:23019:99.94%:0E0
^Cfreeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp my.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from my.mpileup
1665 bases in pileup file
5 variant positions (5 SNP, 0 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ samtools mpileup -f reference.fasta  roommate.bam -d 0 >  roommate.mpileup
[mpileup] 1 samples in 1 input files
[mpileup] Max depth set to maximum value (2147483647)
freeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp roommate.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
5 variant positions (5 SNP, 0 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)


freeman@mashine:~/Workplace/Pracjava -jar /home/freeman/Downloads/VarScan.jar mpileup2snp --min-var-freq 0.95 roommate.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.95
Min avg qual:	15
P-value thresh:	0.01
Input stream not ready, waiting for 5 seconds...
^Cfreeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp roommate.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
^Cfreeman@mashine:~/Workplace/Pracsamtools mpileup -f reference.fasta  roommate.bam -d 0 >  roommate.mpileup
[mpileup] 1 samples in 1 input files
[mpileup] Max depth set to maximum value (2147483647)
freeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp roommate.mpileup > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
^Cfreeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
5 variant positions (5 SNP, 0 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.01 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.01
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
6 variant positions (5 SNP, 1 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.0001 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	1.0E-4
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
1060 variant positions (1039 SNP, 21 indel)
6 were failed by the strand-filter
1033 variant positions reported (1033 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.0005 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	5.0E-4
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
23 variant positions (21 SNP, 2 indel)
0 were failed by the strand-filter
21 variant positions reported (21 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.0003 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	3.0E-4
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
201 variant positions (194 SNP, 7 indel)
2 were failed by the strand-filter
192 variant positions reported (192 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.001 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.001
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
23 variant positions (21 SNP, 2 indel)
0 were failed by the strand-filter
21 variant positions reported (21 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.01 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.01
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
6 variant positions (5 SNP, 1 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$

# %%
java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp my.mpileup 
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from my.mpileup
Chrom	Position	Ref	Var	Cons:Cov:Reads1:Reads2:Freq:P-value	StrandFilter:R1+:R1-:R2+:R2-:pval	SamplesRef	SamplesHet	SamplesHom	SamplesNC	Cons:Cov:Reads1:Reads2:Freq:P-value
KF848938.1	72	A	G	G:16794:6:16787:99.96%:0E0	Pass:4:2:10898:5889:1E0	0	0	1	0	G:16794:6:16787:99.96%:0E0
KF848938.1	117	C	T	T:20663:36:20625:99.82%:0E0	Pass:27:9:13462:7163:1E0	0	0	1	0	T:20663:36:20625:99.82%:0E0
KF848938.1	774	T	C	C:38191:8:38177:99.96%:0E0	Pass:7:1:19806:18371:1E0	0	0	1	0	C:38191:8:38177:99.96%:0E0
KF848938.1	999	C	T	T:32115:40:32070:99.86%:0E0	Pass:23:17:17184:14886:1E0	0	0	1	0	T:32115:40:32070:99.86%:0E0
KF848938.1	1260	A	C	C:23033:2:23019:99.94%:0E0	Pass:0:2:9824:13195:1E0	0	0	1	0	C:23033:2:23019:99.94%:0E0
^Cfreeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp my.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from my.mpileup
1665 bases in pileup file
5 variant positions (5 SNP, 0 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ samtools mpileup -f reference.fasta  roommate.bam -d 0 >  roommate.mpileup
[mpileup] 1 samples in 1 input files
[mpileup] Max depth set to maximum value (2147483647)
freeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp roommate.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
5 variant positions (5 SNP, 0 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar --min-var-freq 0.95 mpileup2snp roommate.mpileup > VarScan_results.vcf
Command not recognized
VarScan v2.4

***NON-COMMERCIAL VERSION***

USAGE: java -jar VarScan.jar [COMMAND] [OPTIONS] 

COMMANDS:
	pileup2snp		Identify SNPs from a pileup file
	pileup2indel		Identify indels a pileup file
	pileup2cns		Call consensus and variants from a pileup file
	mpileup2snp		Identify SNPs from an mpileup file
	mpileup2indel		Identify indels an mpileup file
	mpileup2cns		Call consensus and variants from an mpileup file

	somatic			Call germline/somatic variants from tumor-normal pileups
	copynumber			Determine relative tumor copy number from tumor-normal pileups
	readcounts		Obtain read counts for a list of variants from a pileup file

	filter			Filter SNPs by coverage, frequency, p-value, etc.
	somaticFilter		Filter somatic variants for clusters/indels
	fpfilter		Apply the false-positive filter

	processSomatic		Isolate Germline/LOH/Somatic calls from output
	copyCaller		GC-adjust and process copy number changes from VarScan copynumber output
	compare			Compare two lists of positions/variants
	limit			Restrict pileup/snps/indels to ROI positions


freeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp --min-var-freq 0.95 roommate.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.95
Min avg qual:	15
P-value thresh:	0.01
^Cfreeman@mashine:~/Workplace/Pracjava -jar /home/freeman/Downloads/VarScan.jar mpileup2snp --min-var-freq 0.95 roommate.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.95
Min avg qual:	15
P-value thresh:	0.01
Input stream not ready, waiting for 5 seconds...
^Cfreeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp roommate.mpileup > VarScan_results.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
^Cfreeman@mashine:~/Workplace/Pracsamtools mpileup -f reference.fasta  roommate.bam -d 0 >  roommate.mpileup
[mpileup] 1 samples in 1 input files
[mpileup] Max depth set to maximum value (2147483647)
freeman@mashine:~/Workplace/Prac$ java -jar /home/freeman/Downloads/VarScan.jar mpileup2snp roommate.mpileup > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
^Cfreeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.2
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
5 variant positions (5 SNP, 0 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.01 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.01
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
6 variant positions (5 SNP, 1 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.0001 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	1.0E-4
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
1060 variant positions (1039 SNP, 21 indel)
6 were failed by the strand-filter
1033 variant positions reported (1033 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.0005 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	5.0E-4
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
23 variant positions (21 SNP, 2 indel)
0 were failed by the strand-filter
21 variant positions reported (21 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.0003 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	3.0E-4
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
201 variant positions (194 SNP, 7 indel)
2 were failed by the strand-filter
192 variant positions reported (192 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.001 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.001
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
23 variant positions (21 SNP, 2 indel)
0 were failed by the strand-filter
21 variant positions reported (21 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.01 > VarScan_results_roommate.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.01
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
6 variant positions (5 SNP, 1 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$

# %%
java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.01 > VarScan_results_roommate.html
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.01
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
6 variant positions (5 SNP, 1 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.99 > VarScan_results_roommate.html
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.99
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
5 variant positions (5 SNP, 0 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ java -jar VarScan.jar mpileup2snp roommate.mpileup --min-var-freq 0.99 > VarScan_results_roommate_2.vcf
Only SNPs will be reported
Warning: No p-value threshold provided, so p-values will not be calculated
Min coverage:	8
Min reads2:	2
Min var freq:	0.99
Min avg qual:	15
P-value thresh:	0.01
Reading input from roommate.mpileup
1665 bases in pileup file
5 variant positions (5 SNP, 0 indel)
0 were failed by the strand-filter
5 variant positions reported (5 SNP, 0 indel)
freeman@mashine:~/Workplace/Prac$ cat VarScan_results_roommate_2.vcf | awk 'NR>24 {print $1, $2, $4, $5}'
freeman@mashine:~/Workplace/Prac$ cat VarScan_results_roommate_2.vcf | awk 'NR>1 {print $1, $2, $4, $5}'
KF848938.1 72 G G:16794:6:16787:99.96%:0E0
KF848938.1 117 T T:20663:36:20625:99.82%:0E0
KF848938.1 774 C C:38191:8:38177:99.96%:0E0
KF848938.1 999 T T:32115:40:32070:99.86%:0E0
KF848938.1 1260 C C:23033:2:23019:99.94%:0E0
freeman@mashine:~/Workplace/Prac$ cat VarScan_results_roommate_2.vcf | awk '{print $1, $2, $4, $5}'
Chrom Position Var Cons:Cov:Reads1:Reads2:Freq:P-value
KF848938.1 72 G G:16794:6:16787:99.96%:0E0
KF848938.1 117 T T:20663:36:20625:99.82%:0E0
KF848938.1 774 C C:38191:8:38177:99.96%:0E0
KF848938.1 999 T T:32115:40:32070:99.86%:0E0
KF848938.1 1260 C C:23033:2:23019:99.94%:0E0
freeman@mashine:~/Workplace/Prac$ cat VarScan_results_roommate_2.vcf | awk 'NR>1 {print $1, $2, $4, $5}'
KF848938.1 72 G G:16794:6:16787:99.96%:0E0
KF848938.1 117 T T:20663:36:20625:99.82%:0E0
KF848938.1 774 C C:38191:8:38177:99.96%:0E0
KF848938.1 999 T T:32115:40:32070:99.86%:0E0
KF848938.1 1260 C C:23033:2:23019:99.94%:0E0

# %%
awk '{ {count++; bases += $4} } END{print bases/count}' roommate.mpileup
awk '{if(NR%4==2) {bases += length} } END{print bases/1665}' roommate.fastq # где 1665 - размер reference последовательности
# Out:
#   File "<ipython-input-1-c8b10411995d>", line 1
#     awk '{ {count++; bases += $4} } END{print bases/count}' roommate.mpileup
#                                                           ^
# SyntaxError: invalid syntax
